# %% [markdown]
# # Manage AutoML Workflows with AWS StepFunctions and AutoGluon on Amazon SageMaker
#
# This notebook provides a tutorial on how to run ML experiments using AWS StepFunctions.
# The state machine is able to execute different workloads based on its runtime input parameters.
#
# We provide here a subset of the most common use-cases:
#
# 1) [Train and evaluate a ML model](#train-evaluate)
#
# 2) [Run batch predictions with pre-trained AutoGluon Model](#pretrained-batch)
#
# 3) [Train and deploy model to SageMaker Endpoint](#train-endpoint)
#
# NB:
# - Please select `conda_python3` as Notebook Kernel.
# - Please consider using `Jupyter` over `Jupyter Lab` to avoid potential visualizatoin issues with `stepfunctions` library

# %% [markdown]
# ## Configure Environment
#
# Let's start with install AWS StepFunctions Python SDK

# %%
# !pip install -q stepfunctions==2.2.0

# %% [markdown]
# Import libraries

# %%
from stepfunctions.workflow import Workflow
from stepfunctions.inputs import ExecutionInput
import json
from time import gmtime, strftime, sleep
from IPython.display import display, clear_output
import pandas as pd
from sklearn.model_selection import train_test_split
import sagemaker
import boto3
import os

INPUT_PARAMS_DIR = "./input/"
DATA_DIR = "./data/"
PREFIX = "automl-data"

session = sagemaker.Session()
sagemaker_bucket = session.default_bucket()

# %% [markdown]
# ### Download sample data
#
# __NB: Replace data s3 paths and jump to next section if you would like to use a custom dataset__
#
# Let's download data

# %%
# !aws s3 cp s3://sagemaker-sample-files/datasets/tabular/synthetic/churn.txt {DATA_DIR}/churn.csv
# Out:
# download: s3://sagemaker-sample-files/datasets/tabular/synthetic/churn.txt to data/churn.csv

# %%
df = pd.read_csv(f"{DATA_DIR}/churn.csv")

# %%
[feature for feature in df.columns if 'A' in feature]
# Out:
# ['Account Length', 'Area Code']

# %% [markdown]
# Holdout split in train/test

# %%
train, test = train_test_split(df, test_size=.2)

# %% [markdown]
# Save file locally before upload

# %%
train.to_csv(f"{DATA_DIR}/train.csv", index=False)
test.to_csv(f"{DATA_DIR}/test.csv", index=False)
test.drop('Churn?', axis=1).to_csv(f"{DATA_DIR}/test_batch.csv", index=False, header=False)

# %% [markdown]
# Upload files to S3 for training

# %%
boto3.Session().resource('s3').Bucket(sagemaker_bucket).Object(os.path.join(PREFIX, 'train.csv')).upload_file(f"{DATA_DIR}/train.csv")
boto3.Session().resource('s3').Bucket(sagemaker_bucket).Object(os.path.join(PREFIX, 'test.csv')).upload_file(f"{DATA_DIR}/test.csv")
boto3.Session().resource('s3').Bucket(sagemaker_bucket).Object(os.path.join(PREFIX, 'test_batch.csv')).upload_file(f"{DATA_DIR}/test_batch.csv")

train_uri = f"s3://{sagemaker_bucket}/{PREFIX}/train.csv"
test_uri = f"s3://{sagemaker_bucket}/{PREFIX}/test.csv"
test_batch_uri = f"s3://{sagemaker_bucket}/{PREFIX}/test_batch.csv"
model_output_prefix = f"s3://{sagemaker_bucket}/{PREFIX}/output/"

# %% [markdown]
# Define resource ARNs
#
# __TODO find a way to retrieve ARNs automatically (maybe with Parameter Store)__

# %%
main_machine_arn = "arn:aws:states:eu-west-1:039573824519:stateMachine:MainStateMachineD8FB90C3-GcOHBmyXA0SP"
train_machine_arn = "arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ"
deploy_machine_arn = "arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz"

# %% [markdown]
# Attach SDK to state machines

# %%
main_workflow = Workflow.attach(main_machine_arn)
train_workflow = Workflow.attach(train_machine_arn)
deploy_workflow = Workflow.attach(deploy_machine_arn)

# %% [markdown]
# ### Main State Machine
#
# This state machine is in charge of orchestrating the execution and kickstaring both `Train` and `Deploy` state machines if required.
#
# It includes:
# - Training AutoGluon model (through external state machine)
# - Evaluating trained model
# - Deploying model to SageMaker Endpoint or executes SageMaker Batch Transform Job (through external state machine)

# %%
main_workflow
# Out:
# Workflow(name='MainStateMachineD8FB90C3-GcOHBmyXA0SP', role='arn:aws:iam::039573824519:role/CdkAgSfStack-RoleMainStateMachine7BC2742D-WIE2TQE2CHAT', state_machine_arn='arn:aws:states:eu-west-1:039573824519:stateMachine:MainStateMachineD8FB90C3-GcOHBmyXA0SP')

# %%
main_workflow.render_graph()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-960" class="workflowgraph">
#
#     <svg></svg>
#
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-960')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 600,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "IsTraining", "States": {"IsTraining": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Train", "BooleanEquals": true, "Next": "TrainSteps"}, {"Variable": "$.Parameters.Flow.Train", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "TrainSteps"}, "TrainSteps": {"Next": "PassModelName", "Type": "Task", "ResultPath": "$.TrainStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ"}}, "PassModelName": {"Type": "Pass", "ResultPath": "$.Parameters.PretrainedModel", "Parameters": {"Name.$": "$.TrainStepsOutput.Output.TrainingOutput.TrainingJobName"}, "Next": "IsEvaluation"}, "IsEvaluation": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": true, "Next": "ModelValidation"}, {"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "ModelValidation"}, "ModelValidation": {"Next": "EvaluationResults", "Retry": [{"ErrorEquals": ["Lambda.ServiceException", "Lambda.AWSLambdaException", "Lambda.SdkClientException"], "IntervalSeconds": 2, "MaxAttempts": 6, "BackoffRate": 2}], "Type": "Task", "ResultPath": "$.ModelValidationLambdaOutput", "Resource": "arn:aws:states:::lambda:invoke", "Parameters": {"FunctionName": "arn:aws:lambda:eu-west-1:039573824519:function:CdkAgSfStack-ValidateModelPerformancesBE885D29-ApRHHGMvIN0k", "Payload": {"ModelPath.$": "$.TrainStepsOutput.Output.TrainingOutput.ModelArtifacts.S3ModelArtifacts", "EvalThreshold.$": "$.Parameters.Evaluation.Threshold", "EvalMetric.$": "$.Parameters.Evaluation.Metric"}}}, "EvaluationResults": {"Type": "Choice", "Choices": [{"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": true, "Next": "IsDeploy"}, {"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "IsDeploy"}, "IsDeploy": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": true, "Next": "DeploySteps"}, {"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "DeploySteps"}, "DeploySteps": {"End": true, "Type": "Task", "ResultPath": "$.DeployStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz"}}, "Skipped Deployment": {"Type": "Succeed"}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-960';
#
#     var graph = new sfn.StateMachineGraph(definition, elementId, options);
#     graph.render();
# });
#
# </script>

# %% [markdown]
# ### Train State Machine
#
# This state machine performs to main tasks:
#
# 1) Starts a new SageMaker Training Job using AutoGluon tabular
#
# 2) Save trained model to SageMaker Model Registry

# %%
train_workflow
# Out:
# Workflow(name='TrainStateMachineAA65CDDB-ovlcReYQjVFQ', role='arn:aws:iam::039573824519:role/CdkAgSfStack-RoleTrainStateMachine78727C93-18ATNL4AB5UC4', state_machine_arn='arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ')

# %%
train_workflow.render_graph()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-267" class="workflowgraph">
#
#     <svg></svg>
#
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-267')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 600,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "TrainingStep", "States": {"TrainingStep": {"Next": "CreateModel", "Type": "Task", "ResultPath": "$.TrainingOutput", "Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"TrainingJobName.$": "$$.Execution.Name", "RoleArn": "arn:aws:iam::039573824519:role/CdkAgSfStack-RoleTrainE6753192-KSVJEQKZG4FS", "AlgorithmSpecification": {"TrainingInputMode": "File", "TrainingImage": "763104351884.dkr.ecr.eu-west-1.amazonaws.com/autogluon-training:0.3.1-cpu-py37"}, "InputDataConfig": [{"ChannelName": "train", "DataSource": {"S3DataSource": {"S3Uri.$": "$.Parameters.Train.TrainDataPath", "S3DataType": "S3Prefix", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/csv"}, {"ChannelName": "test", "DataSource": {"S3DataSource": {"S3Uri.$": "$.Parameters.Train.TestDataPath", "S3DataType": "S3Prefix", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/csv"}], "OutputDataConfig": {"S3OutputPath.$": "$.Parameters.Train.TrainingOutput"}, "ResourceConfig": {"InstanceCount.$": "$.Parameters.Train.InstanceCount", "InstanceType.$": "$.Parameters.Train.InstanceType", "VolumeSizeInGB": 30}, "StoppingCondition": {"MaxRuntimeInSeconds": 3600}, "HyperParameters": {"fit_args.$": "$.Parameters.Train.FitArgs", "init_args.$": "$.Parameters.Train.InitArgs", "feature_importance.$": "$.Parameters.Train.FeatureImportance", "leaderboard.$": "$.Parameters.Train.Leaderboard", "sagemaker_submit_directory": "s3://cdkagsfstack-cdkautogluonstepfunctionsf9c67a56-1kayo5zlspvmj/sourcedir.tar.gz", "sagemaker_program": "tabular_train.py", "sagemaker_region": "eu-west-1", "sagemaker_container_log_level": "20", "sagemaker_job_name.$": "$$.Execution.Name"}}}, "CreateModel": {"End": true, "Type": "Task", "ResultPath": "$.CreateModelOutput", "Resource": "arn:aws:states:::sagemaker:createModel", "Parameters": {"ExecutionRoleArn": "arn:aws:iam::039573824519:role/CdkAgSfStack-RoleTrainE6753192-KSVJEQKZG4FS", "ModelName.$": "$$.Execution.Name", "PrimaryContainer": {"Image": "763104351884.dkr.ecr.eu-west-1.amazonaws.com/autogluon-inference:0.3.1-cpu-py37", "ModelDataUrl.$": "$.TrainingOutput.ModelArtifacts.S3ModelArtifacts", "Environment": {"SAGEMAKER_CONTAINER_LOG_LEVEL": "20", "SAGEMAKER_PROGRAM": "tabular_serve.py", "SAGEMAKER_SUBMIT_DIRECTORY.$": "$.TrainingOutput.ModelArtifacts.S3ModelArtifacts"}}}}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-267';
#
#     var graph = new sfn.StateMachineGraph(definition, elementId, options);
#     graph.render();
# });
#
# </script>

# %% [markdown]
# ### Deploy State Machine
#
# This state machine performs:
#
# - Online deployment, by spinning up a new SageMaker Endpoint and waiting for it to became available
#
# - Offline deployment, by running a SageMaker Batch Transform Job and waiting for its completion

# %%
deploy_workflow
# Out:
# Workflow(name='DeployStateMachine357A3963-KbeWPmnhskxz', role='arn:aws:iam::039573824519:role/CdkAgSfStack-RoleDeployStateMachine1E6B6BE7-1NZ12H0ZDTH1F', state_machine_arn='arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz')

# %%
deploy_workflow.render_graph()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-708" class="workflowgraph">
#
#     <svg></svg>
#
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-708')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 600,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "ChoiceDeploymentMode", "States": {"ChoiceDeploymentMode": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Deploy.Mode", "StringEquals": "endpoint", "Next": "EndpointConfig"}, {"Variable": "$.Parameters.Deploy.Mode", "StringEquals": "batch", "Next": "BatchInference"}], "Default": "Unexpected Mode"}, "Unexpected Mode": {"Type": "Fail"}, "EndpointConfig": {"Next": "CreateEndpoint", "Type": "Task", "ResultPath": "$.CreateEndpointConfigOutput", "Resource": "arn:aws:states:::sagemaker:createEndpointConfig", "Parameters": {"EndpointConfigName.$": "$$.Execution.Name", "ProductionVariants": [{"InitialInstanceCount": 1, "InstanceType.$": "$.Parameters.Deploy.InstanceType", "ModelName.$": "$.Parameters.PretrainedModel.Name", "VariantName": "AllTraffic"}]}}, "CreateEndpoint": {"Next": "WaitForEndpoint", "Type": "Task", "ResultPath": "$.CreateEndpointOutput", "Resource": "arn:aws:states:::sagemaker:createEndpoint", "Parameters": {"EndpointConfigName.$": "$$.Execution.Name", "EndpointName.$": "$$.Execution.Name"}}, "WaitForEndpoint": {"Type": "Wait", "Seconds": 60, "Next": "EndpointStatusLambdaStep"}, "ChoiceEndpointStatus": {"Type": "Choice", "Choices": [{"Variable": "$.EndpointStatusLambdaOutput.Payload.EndpointStatus", "StringEquals": "InService", "Next": "Deployment Succeded"}, {"Variable": "$.EndpointStatusLambdaOutput.Payload.EndpointStatus", "StringEquals": "Creating", "Next": "WaitForEndpoint"}], "Default": "Deployment Failed"}, "EndpointStatusLambdaStep": {"Next": "ChoiceEndpointStatus", "Retry": [{"ErrorEquals": ["Lambda.ServiceException", "Lambda.AWSLambdaException", "Lambda.SdkClientException"], "IntervalSeconds": 2, "MaxAttempts": 6, "BackoffRate": 2}], "Type": "Task", "ResultPath": "$.EndpointStatusLambdaOutput", "Resource": "arn:aws:states:::lambda:invoke", "Parameters": {"FunctionName": "arn:aws:lambda:eu-west-1:039573824519:function:CdkAgSfStack-GetEndpointStatus95E8DAC7-VvLvpUcVZ6tZ", "Payload": {"EndpointName.$": "$$.Execution.Name"}}}, "Deployment Failed": {"Type": "Fail"}, "Deployment Succeded": {"Type": "Succeed"}, "BatchInference": {"Next": "Deployment Succeded", "Type": "Task", "Resource": "arn:aws:states:::sagemaker:createTransformJob.sync", "Parameters": {"BatchStrategy": "MultiRecord", "ModelName.$": "$.Parameters.PretrainedModel.Name", "TransformInput": {"ContentType.$": "$.Parameters.Deploy.BatchContentType", "DataSource": {"S3DataSource": {"S3Uri.$": "$.Parameters.Deploy.BatchInputDataPath", "S3DataType": "S3Prefix"}}, "SplitType": "Line"}, "TransformJobName.$": "$$.Execution.Name", "TransformOutput": {"S3OutputPath.$": "$.Parameters.Deploy.BatchOutputDataPath", "AssembleWith": "Line"}, "TransformResources": {"InstanceCount.$": "$.Parameters.Deploy.InstanceCount", "InstanceType.$": "$.Parameters.Deploy.InstanceType"}}}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-708';
#
#     var graph = new sfn.StateMachineGraph(definition, elementId, options);
#     graph.render();
# });
#
# </script>

# %% [markdown]
# <a id='train-evaluate'></a>
# ## 1) Train and Evaluate ML Model
#
# Sample execution that consists of __training__ a new AutoGluon model and __evaluating__ its perfomance on a fresh test set.
#
# Let's start by loading the input parameters:

# %%
input_params_path = f"{INPUT_PARAMS_DIR}train_evaluate_input.json"
with open(input_params_path, "r") as input_file:
    input_params = json.load(input_file)

# %% [markdown]
# Replace data placeholder with train and test s3 data uri

# %%
input_params['Parameters']['Train']['TrainDataPath'] = train_uri
input_params['Parameters']['Train']['TestDataPath'] = test_uri
input_params['Parameters']['Train']["TrainingOutput"] = model_output_prefix

# %% [markdown]
# Set target label and [problem type (options: `binary`, `multiclass`, `regression`, `quantile`)](https://auto.gluon.ai/stable/api/autogluon.task.html#autogluon.tabular.TabularPredictor)

# %%
# Double JSON encoding is needed to successfully forward parameters from State Machine to SageMaker Training Job

ag_init_params = json.loads(json.loads(input_params['Parameters']['Train']["InitArgs"]))
ag_init_params['problem_type'] = 'binary'
ag_init_params['label'] = 'Churn?'

ag_fit_params = json.loads(json.loads(input_params['Parameters']['Train']['FitArgs']))
ag_fit_params['presets'] = 'medium_quality_faster_train'

input_params['Parameters']['Train']["InitArgs"] = json.dumps(json.dumps(ag_init_params))

# %% [markdown]
# Let's explore the parameters structure

# %%
print(f"Parameters sections: {list(input_params['Parameters'].keys())}")
# Out:
# Parameters sections: ['Flow', 'Train', 'Evaluation']

# %% [markdown]
# If we inspect the `Flow` section, we can see which stages of the pipeline have been selected.

# %%
print('Selected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if v])
print('Unselected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if not v])
# Out:
# Selected steps: ['Train', 'Evaluate']
# Unselected steps: ['Deploy']

# %%
input_params
# Out:
# {'Parameters': {'Flow': {'Train': True, 'Evaluate': True, 'Deploy': False},
#   'Train': {'TrainDataPath': 's3://sagemaker-eu-west-1-039573824519/automl-data/train.csv',
#    'TestDataPath': 's3://sagemaker-eu-west-1-039573824519/automl-data/test.csv',
#    'TrainingOutput': 's3://stepfunctions-mlops/output/training/',
#    'InstanceCount': 1,
#    'InstanceType': 'ml.m5.2xlarge',
#    'FitArgs': '"{\\"presets\\": \\"medium_quality_faster_train\\"}"',
#    'InitArgs': '"{\\"label\\": \\"Churn?\\", \\"problem_type\\": \\"binary\\"}"',
#    'FeatureImportance': 'true',
#    'Leaderboard': 'true'},
#   'Evaluation': {'Threshold': '0.6', 'Metric': 'accuracy'}}}

# %% [markdown]
# Let's start the execution and wait for completion

# %%
train_execution_name = f"train-evaluate-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
train_execution = main_workflow.execute(name=train_execution_name, inputs=input_params)

# %%
status = train_execution.describe()['status']
while status == 'RUNNING':
    clear_output(wait=True)
    display(train_execution.render_progress())
    sleep(60)
    status = train_execution.describe()['status']

clear_output(wait=True)
display(train_execution.render_progress())
print(f"Execution terminated, status: {status}")
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-755" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/executions/details/arn:aws:states:eu-west-1:039573824519:execution:MainStateMachineD8FB90C3-GcOHBmyXA0SP:train-evaluate-2022-01-26-10-42-09" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-755')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "IsTraining", "States": {"IsTraining": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Train", "BooleanEquals": true, "Next": "TrainSteps"}, {"Variable": "$.Parameters.Flow.Train", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "TrainSteps"}, "TrainSteps": {"Next": "PassModelName", "Type": "Task", "ResultPath": "$.TrainStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ"}}, "PassModelName": {"Type": "Pass", "ResultPath": "$.Parameters.PretrainedModel", "Parameters": {"Name.$": "$.TrainStepsOutput.Output.TrainingOutput.TrainingJobName"}, "Next": "IsEvaluation"}, "IsEvaluation": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": true, "Next": "ModelValidation"}, {"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "ModelValidation"}, "ModelValidation": {"Next": "EvaluationResults", "Retry": [{"ErrorEquals": ["Lambda.ServiceException", "Lambda.AWSLambdaException", "Lambda.SdkClientException"], "IntervalSeconds": 2, "MaxAttempts": 6, "BackoffRate": 2}], "Type": "Task", "ResultPath": "$.ModelValidationLambdaOutput", "Resource": "arn:aws:states:::lambda:invoke", "Parameters": {"FunctionName": "arn:aws:lambda:eu-west-1:039573824519:function:CdkAgSfStack-ValidateModelPerformancesBE885D29-ApRHHGMvIN0k", "Payload": {"ModelPath.$": "$.TrainStepsOutput.Output.TrainingOutput.ModelArtifacts.S3ModelArtifacts", "EvalThreshold.$": "$.Parameters.Evaluation.Threshold", "EvalMetric.$": "$.Parameters.Evaluation.Metric"}}}, "EvaluationResults": {"Type": "Choice", "Choices": [{"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": true, "Next": "IsDeploy"}, {"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "IsDeploy"}, "IsDeploy": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": true, "Next": "DeploySteps"}, {"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "DeploySteps"}, "DeploySteps": {"End": true, "Type": "Task", "ResultPath": "$.DeployStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz"}}, "Skipped Deployment": {"Type": "Succeed"}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-755';
#     var events = { 'events': [{"timestamp": 1643193730.049, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n            \"Deploy\": false\n        },\n        \"Train\": {\n            \"TrainDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/train.csv\",\n            \"TestDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test.csv\",\n            \"TrainingOutput\": \"s3://stepfunctions-mlops/output/training/\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"FitArgs\": \"\\\"{\\\\\\\"presets\\\\\\\": \\\\\\\"medium_quality_faster_train\\\\\\\"}\\\"\",\n            \"InitArgs\": \"\\\"{\\\\\\\"label\\\\\\\": \\\\\\\"Churn?\\\\\\\", \\\\\\\"problem_type\\\\\\\": \\\\\\\"binary\\\\\\\"}\\\"\",\n            \"FeatureImportance\": \"true\",\n            \"Leaderboard\": \"true\"\n        },\n        \"Evaluation\": {\n            \"Threshold\": \"0.6\",\n            \"Metric\": \"accuracy\"\n        }\n    }\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::039573824519:role/CdkAgSfStack-RoleMainStateMachine7BC2742D-WIE2TQE2CHAT"}}, {"timestamp": 1643193730.078, "type": "ChoiceStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "IsTraining", "input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n            \"Deploy\": false\n        },\n        \"Train\": {\n            \"TrainDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/train.csv\",\n            \"TestDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test.csv\",\n            \"TrainingOutput\": \"s3://stepfunctions-mlops/output/training/\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"FitArgs\": \"\\\"{\\\\\\\"presets\\\\\\\": \\\\\\\"medium_quality_faster_train\\\\\\\"}\\\"\",\n            \"InitArgs\": \"\\\"{\\\\\\\"label\\\\\\\": \\\\\\\"Churn?\\\\\\\", \\\\\\\"problem_type\\\\\\\": \\\\\\\"binary\\\\\\\"}\\\"\",\n            \"FeatureImportance\": \"true\",\n            \"Leaderboard\": \"true\"\n        },\n        \"Evaluation\": {\n            \"Threshold\": \"0.6\",\n            \"Metric\": \"accuracy\"\n        }\n    }\n}", "inputDetails": {"truncated": false}}}, {"timestamp": 1643193730.078, "type": "ChoiceStateExited", "id": 3, "previousEventId": 2, "stateExitedEventDetails": {"name": "IsTraining", "output": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n            \"Deploy\": false\n        },\n        \"Train\": {\n            \"TrainDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-
# Execution terminated, status: SUCCEEDED

# %% [markdown]
# Let's explore the execution output.
#
# Here's some snippet from Train state machine output:

# %%
training_output = train_execution.get_output()['TrainStepsOutput']['Output']['TrainingOutput']

print(f"Training Job Name: {training_output['TrainingJobName']}")
print(f"Model artifacts: {training_output['ModelArtifacts']['S3ModelArtifacts']}")
# Out:
# Training Job Name: ef208ec4-04fd-45af-bb57-885d618daee1
# Model artifacts: s3://stepfunctions-mlops/output/training/ef208ec4-04fd-45af-bb57-885d618daee1/output/model.tar.gz

# %% [markdown]
# Here's instead we have the evaluation step output

# %%
evaluation_output = train_execution.get_output()['ModelValidationLambdaOutput']['Payload']
print(f"Has model outperfomed the threshold? {evaluation_output['IsValid']}")
print("\nScores")
for metric, value in evaluation_output['Scores'].items():
      print(f"\t{metric}: {value}")
# Out:
# Has model outperfomed the threshold? True
#
# Scores
# 	accuracy: 0.963
# 	balanced_accuracy: 0.9624517803708555
# 	mcc: 0.9261342082184997
# 	roc_auc: 0.9893606367594807
# 	f1: 0.9647954329210275
# 	precision: 0.9530075187969925
# 	recall: 0.976878612716763

# %% [markdown]
# <a id='pretrained-batch'></a>
# ## 2) Run batch predictions with pre-trained AutoGluon Model
#
# Load an already trained model and run batch inference on new set.
#
# Let's load a new set of input parameters:

# %%
input_params_path = f"{INPUT_PARAMS_DIR}pretrained_batch_input.json"
with open(input_params_path, "r") as input_file:
    input_params = json.load(input_file)

# %% [markdown]
# Let's explore the parameters section

# %%
print(f"Parameters sections: {list(input_params['Parameters'].keys())}")
# Out:
# Parameters sections: ['Flow', 'PretrainedModel', 'Deploy']

# %% [markdown]
# Fill the value of `PretrainedModel` with model trained at the previous step

# %%
input_params['Parameters']['PretrainedModel']['Name'] = train_execution.get_output()['TrainStepsOutput']['Output']['TrainingOutput']['TrainingJobName']
input_params['Parameters']['Deploy']['BatchOutputDataPath'] = f"s3://{sagemaker_bucket}/batch-out/"
input_params['Parameters']['Deploy']['BatchInputDataPath'] = test_batch_uri

# %%
print('Selected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if v])
print('Unselected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if not v])
# Out:
# Selected steps: ['Deploy']
# Unselected steps: ['Train', 'Evaluate']

# %%
batch_execution_name = f"pretrained-batch-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
batch_execution = main_workflow.execute(name=batch_execution_name, inputs=input_params)

# %%
status = batch_execution.describe()['status']
while status == 'RUNNING':
    clear_output(wait=True)
    display(batch_execution.render_progress())
    sleep(60)
    status = batch_execution.describe()['status']

clear_output(wait=True)
display(batch_execution.render_progress())
print(f"Execution terminated, status: {status}")
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-190" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/executions/details/arn:aws:states:eu-west-1:039573824519:execution:MainStateMachineD8FB90C3-GcOHBmyXA0SP:pretrained-batch-2022-01-26-11-12-04" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-190')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "IsTraining", "States": {"IsTraining": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Train", "BooleanEquals": true, "Next": "TrainSteps"}, {"Variable": "$.Parameters.Flow.Train", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "TrainSteps"}, "TrainSteps": {"Next": "PassModelName", "Type": "Task", "ResultPath": "$.TrainStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ"}}, "PassModelName": {"Type": "Pass", "ResultPath": "$.Parameters.PretrainedModel", "Parameters": {"Name.$": "$.TrainStepsOutput.Output.TrainingOutput.TrainingJobName"}, "Next": "IsEvaluation"}, "IsEvaluation": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": true, "Next": "ModelValidation"}, {"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "ModelValidation"}, "ModelValidation": {"Next": "EvaluationResults", "Retry": [{"ErrorEquals": ["Lambda.ServiceException", "Lambda.AWSLambdaException", "Lambda.SdkClientException"], "IntervalSeconds": 2, "MaxAttempts": 6, "BackoffRate": 2}], "Type": "Task", "ResultPath": "$.ModelValidationLambdaOutput", "Resource": "arn:aws:states:::lambda:invoke", "Parameters": {"FunctionName": "arn:aws:lambda:eu-west-1:039573824519:function:CdkAgSfStack-ValidateModelPerformancesBE885D29-ApRHHGMvIN0k", "Payload": {"ModelPath.$": "$.TrainStepsOutput.Output.TrainingOutput.ModelArtifacts.S3ModelArtifacts", "EvalThreshold.$": "$.Parameters.Evaluation.Threshold", "EvalMetric.$": "$.Parameters.Evaluation.Metric"}}}, "EvaluationResults": {"Type": "Choice", "Choices": [{"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": true, "Next": "IsDeploy"}, {"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "IsDeploy"}, "IsDeploy": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": true, "Next": "DeploySteps"}, {"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "DeploySteps"}, "DeploySteps": {"End": true, "Type": "Task", "ResultPath": "$.DeployStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz"}}, "Skipped Deployment": {"Type": "Succeed"}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-190';
#     var events = { 'events': [{"timestamp": 1643195524.204, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": false,\n            \"Evaluate\": false,\n            \"Deploy\": true\n        },\n        \"PretrainedModel\": {\n            \"Name\": \"ef208ec4-04fd-45af-bb57-885d618daee1\"\n        },\n        \"Deploy\": {\n            \"BatchInputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test_batch.csv\",\n            \"BatchOutputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/batch-out/\",\n            \"BatchContentType\": \"text/csv\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"Mode\": \"batch\"\n        }\n    }\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::039573824519:role/CdkAgSfStack-RoleMainStateMachine7BC2742D-WIE2TQE2CHAT"}}, {"timestamp": 1643195524.229, "type": "ChoiceStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "IsTraining", "input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": false,\n            \"Evaluate\": false,\n            \"Deploy\": true\n        },\n        \"PretrainedModel\": {\n            \"Name\": \"ef208ec4-04fd-45af-bb57-885d618daee1\"\n        },\n        \"Deploy\": {\n            \"BatchInputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test_batch.csv\",\n            \"BatchOutputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/batch-out/\",\n            \"BatchContentType\": \"text/csv\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"Mode\": \"batch\"\n        }\n    }\n}", "inputDetails": {"truncated": false}}}, {"timestamp": 1643195524.229, "type": "ChoiceStateExited", "id": 3, "previousEventId": 2, "stateExitedEventDetails": {"name": "IsTraining", "output": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": false,\n            \"Evaluate\": false,\n            \"Deploy\": true\n        },\n        \"PretrainedModel\": {\n            \"Name\": \"ef208ec4-04fd-45af-bb57-885d618daee1\"\n        },\n        \"Deploy\": {\n            \"BatchInputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test_batch.csv\",\n            \"BatchOutputDataPath\": \"s3://sagemaker-eu-west-1-039573824519/batch-out/\",\n            \"BatchContentType\": \"text/csv\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"Mode\": \"batch\"\n        }\n    }\n}", "outputDetails": {"truncated": false}}}, {"timestamp": 1643195524.33, "type": "ChoiceStateEntered", "id": 4, "previousEventId": 3, "stateEnteredEventDetails": {"name": "IsDeploy", "input": "{\n    \"Parameters\": {\n        \"Flow\": {\n

# %% [markdown]
# Let's explore brifly the predictions saved on S3

# %%
batch_output_uri = batch_execution.get_output()['Parameters']['Deploy']['BatchOutputDataPath']
batch_filename = 'batch_out.json'

# %%
# !aws s3 cp {batch_output_uri}test_batch.csv.out {batch_filename}
# Out:
# download: s3://sagemaker-eu-west-1-039573824519/batch-out/test_batch.csv.out to ./batch_out.json

# %%
with open(batch_filename, "r") as input_file:
    batch_predictions = json.load(input_file)

# %%
batch_predictions[:10]
# Out:
# [['True.', 0.04348301887512207, 0.9565169811248779],
#  ['True.', 0.009195685386657715, 0.9908043146133423],
#  ['True.', 0.0015034675598144531, 0.9984965324401855],
#  ['False.', 0.9803850054740906, 0.019614998251199722],
#  ['True.', 0.018985986709594727, 0.9810140132904053],
#  ['False.', 0.9465275406837463, 0.053472474217414856],
#  ['True.', 0.06416893005371094, 0.9358310699462891],
#  ['False.', 0.9860401749610901, 0.013959839008748531],
#  ['False.', 0.9652785062789917, 0.03472146764397621],
#  ['True.', 0.012667417526245117, 0.9873325824737549]]

# %% [markdown]
# Clean up prediction file from local memory

# %%
# !rm {batch_filename}

# %% [markdown]
# <a id='train-endpoint'></a>
# ## 3) Train, evaluate and deploy a new AutoGluon model for online prediction
#
# Let's bring everything together and train, evaluate and deploy model to SageMaker Endpoint.
#
# Let's load a new set of input parameters:

# %%
input_params_path = f"{INPUT_PARAMS_DIR}train_endpoint_input.json"
with open(input_params_path, "r") as input_file:
    input_params = json.load(input_file)

# %% [markdown]
# Let's explore the parameters structure

# %%
print(f"Parameters sections: {list(input_params['Parameters'].keys())}")
# Out:
# Parameters sections: ['Flow', 'Train', 'Evaluation', 'Deploy']

# %% [markdown]
# Let's now replace placeholders in input parameters

# %%
input_params['Parameters']['Train']['TrainDataPath'] = train_uri
input_params['Parameters']['Train']['TestDataPath'] = test_uri
input_params['Parameters']['Train']["TrainingOutput"] = model_output_prefix

# Double JSON encoding is needed to successfully forward parameters from State Machine to SageMaker Training Job
ag_init_params = json.loads(json.loads(input_params['Parameters']['Train']["InitArgs"]))
ag_init_params['problem_type'] = 'binary'
ag_init_params['label'] = 'Churn?'

ag_fit_params = json.loads(json.loads(input_params['Parameters']['Train']['FitArgs']))
ag_fit_params['presets'] = 'optimize_for_deployment'

input_params['Parameters']['Train']["InitArgs"] = json.dumps(json.dumps(ag_init_params))

# %%
print('Selected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if v])
print('Unselected steps:', [k for k, v in input_params['Parameters']['Flow'].items() if not v])
# Out:
# Selected steps: ['Train', 'Evaluate', 'Deploy']
# Unselected steps: []

# %%
endpoint_execution_name = f"train-endpoint-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
endpoint_execution = main_workflow.execute(name=endpoint_execution_name, inputs=input_params)

# %%
status = endpoint_execution.describe()['status']
while status == 'RUNNING':
    clear_output(wait=True)
    display(endpoint_execution.render_progress())
    sleep(60)
    status = endpoint_execution.describe()['status']

clear_output(wait=True)
display(endpoint_execution.render_progress())
print(f"Execution terminated, status: {status}")
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-500" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/executions/details/arn:aws:states:eu-west-1:039573824519:execution:MainStateMachineD8FB90C3-GcOHBmyXA0SP:train-endpoint-2022-01-26-15-11-31" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-500')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "IsTraining", "States": {"IsTraining": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Train", "BooleanEquals": true, "Next": "TrainSteps"}, {"Variable": "$.Parameters.Flow.Train", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "TrainSteps"}, "TrainSteps": {"Next": "PassModelName", "Type": "Task", "ResultPath": "$.TrainStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:TrainStateMachineAA65CDDB-ovlcReYQjVFQ"}}, "PassModelName": {"Type": "Pass", "ResultPath": "$.Parameters.PretrainedModel", "Parameters": {"Name.$": "$.TrainStepsOutput.Output.TrainingOutput.TrainingJobName"}, "Next": "IsEvaluation"}, "IsEvaluation": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": true, "Next": "ModelValidation"}, {"Variable": "$.Parameters.Flow.Evaluate", "BooleanEquals": false, "Next": "IsDeploy"}], "Default": "ModelValidation"}, "ModelValidation": {"Next": "EvaluationResults", "Retry": [{"ErrorEquals": ["Lambda.ServiceException", "Lambda.AWSLambdaException", "Lambda.SdkClientException"], "IntervalSeconds": 2, "MaxAttempts": 6, "BackoffRate": 2}], "Type": "Task", "ResultPath": "$.ModelValidationLambdaOutput", "Resource": "arn:aws:states:::lambda:invoke", "Parameters": {"FunctionName": "arn:aws:lambda:eu-west-1:039573824519:function:CdkAgSfStack-ValidateModelPerformancesBE885D29-ApRHHGMvIN0k", "Payload": {"ModelPath.$": "$.TrainStepsOutput.Output.TrainingOutput.ModelArtifacts.S3ModelArtifacts", "EvalThreshold.$": "$.Parameters.Evaluation.Threshold", "EvalMetric.$": "$.Parameters.Evaluation.Metric"}}}, "EvaluationResults": {"Type": "Choice", "Choices": [{"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": true, "Next": "IsDeploy"}, {"Variable": "$.ModelValidationLambdaOutput.Payload.IsValid", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "IsDeploy"}, "IsDeploy": {"Type": "Choice", "Choices": [{"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": true, "Next": "DeploySteps"}, {"Variable": "$.Parameters.Flow.Deploy", "BooleanEquals": false, "Next": "Skipped Deployment"}], "Default": "DeploySteps"}, "DeploySteps": {"End": true, "Type": "Task", "ResultPath": "$.DeployStepsOutput", "ResultSelector": {"Output.$": "$.Output"}, "Resource": "arn:aws:states:::states:startExecution.sync:2", "Parameters": {"Input.$": "$", "StateMachineArn": "arn:aws:states:eu-west-1:039573824519:stateMachine:DeployStateMachine357A3963-KbeWPmnhskxz"}}, "Skipped Deployment": {"Type": "Succeed"}}, "TimeoutSeconds": 3600};
#     var elementId = '#graph-500';
#     var events = { 'events': [{"timestamp": 1643209893.772, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n            \"Deploy\": true\n        },\n        \"Train\": {\n            \"TrainDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/train.csv\",\n            \"TestDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test.csv\",\n            \"TrainingOutput\": \"s3://stepfunctions-mlops/output/training/\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"FitArgs\": \"\\\"{\\\\\\\"presets\\\\\\\": \\\\\\\"medium_quality_faster_train\\\\\\\"}\\\"\",\n            \"InitArgs\": \"\\\"{\\\\\\\"label\\\\\\\": \\\\\\\"Churn?\\\\\\\", \\\\\\\"problem_type\\\\\\\": \\\\\\\"binary\\\\\\\"}\\\"\"\n        },\n        \"Evaluation\": {\n            \"Threshold\": \"0.6\",\n            \"Metric\": \"accuracy\"\n        },\n        \"Deploy\": {\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"Mode\": \"endpoint\"\n        }\n    }\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::039573824519:role/CdkAgSfStack-RoleMainStateMachine7BC2742D-WIE2TQE2CHAT"}}, {"timestamp": 1643209894.076, "type": "ChoiceStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "IsTraining", "input": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n            \"Deploy\": true\n        },\n        \"Train\": {\n            \"TrainDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/train.csv\",\n            \"TestDataPath\": \"s3://sagemaker-eu-west-1-039573824519/automl-data/test.csv\",\n            \"TrainingOutput\": \"s3://stepfunctions-mlops/output/training/\",\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"FitArgs\": \"\\\"{\\\\\\\"presets\\\\\\\": \\\\\\\"medium_quality_faster_train\\\\\\\"}\\\"\",\n            \"InitArgs\": \"\\\"{\\\\\\\"label\\\\\\\": \\\\\\\"Churn?\\\\\\\", \\\\\\\"problem_type\\\\\\\": \\\\\\\"binary\\\\\\\"}\\\"\"\n        },\n        \"Evaluation\": {\n            \"Threshold\": \"0.6\",\n            \"Metric\": \"accuracy\"\n        },\n        \"Deploy\": {\n            \"InstanceCount\": 1,\n            \"InstanceType\": \"ml.m5.2xlarge\",\n            \"Mode\": \"endpoint\"\n        }\n    }\n}", "inputDetails": {"truncated": false}}}, {"timestamp": 1643209894.076, "type": "ChoiceStateExited", "id": 3, "previousEventId": 2, "stateExitedEventDetails": {"name": "IsTraining", "output": "{\n    \"Parameters\": {\n        \"Flow\": {\n            \"Train\": true,\n            \"Evaluate\": true,\n
# Execution terminated, status: SUCCEEDED

# %% [markdown]
# Let's test the endpoint

# %%
endpoint_arn = endpoint_execution.get_output()['DeployStepsOutput']['Output']['CreateEndpointOutput']['EndpointArn']
endpoint_name = endpoint_arn.split('/')[-1]

# %%
sm_runtime = boto3.client('runtime.sagemaker')

# Loading a snippet of the test file
with open(f"{DATA_DIR}test_batch.csv", "r") as batch_file:
    batch_file.readline()
    samples = batch_file.readlines()[:10]
    
payload = {"instances": ''.join(samples)}

response = sm_runtime.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType='text/csv',
    Body=''.join(samples)
)

# %%
results = json.loads(response['Body'].read().decode())

# %% [markdown]
# Here's your live predictions

# %%
results
# Out:
# [['True.', 0.04431271553039551, 0.9556872844696045],
#  ['True.', 0.02011626958847046, 0.9798837304115295],
#  ['True.', 0.008425593376159668, 0.9915744066238403],
#  ['False.', 0.9018359184265137, 0.09816406667232513],
#  ['True.', 0.2541276216506958, 0.7458723783493042],
#  ['True.', 0.42594635486602783, 0.5740536451339722],
#  ['True.', 0.4489116668701172, 0.5510883331298828],
#  ['False.', 0.9520736932754517, 0.047926317900419235],
#  ['False.', 0.9109795093536377, 0.0890204906463623],
#  ['True.', 0.05050283670425415, 0.9494971632957458]]

# %% [markdown]
# __Optional__: delete endpoint to avoid additional charges

# %%
sm_client = boto3.client('sagemaker')
sm_client.delete_endpoint(EndpointName=endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '60f01fdd-6656-4a2b-a79c-e19c5c109f81',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '60f01fdd-6656-4a2b-a79c-e19c5c109f81',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Wed, 26 Jan 2022 15:37:39 GMT'},
#   'RetryAttempts': 0}}
